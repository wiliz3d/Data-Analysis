# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import scipy as sp  
import seaborn as sns
from plotly import express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go

# %%
df = pd.read_csv(r'C:\Users\willy\OneDrive\Documents\flash2\RANDOM\Pandas class\heroes\Heroes_edit.csv')

df

# %%
df.head()

# %%
df.shape
# Out:
# (681, 12)

# %%
df.head()
# Out:
#           Name                Identity         Birth place      Publisher  \
# 0       A-Bomb  Richard Milhouse Jones  Scarsdale, Arizona  Marvel Comics
# 1      Abraxas                 Abraxas    Within Eternity   Marvel Comics
# 2  Abomination            Emil Blonsky  Zagreb, Yugoslavia  Marvel Comics
# 3  Adam Monroe                     NaN                 NaN   NBC - Heroes
# 4     Agent 13           Sharon Carter                 NaN  Marvel Comics
#
#    Height  Weight Gender  First appearance Eye color Hair color  Strength  \
# 0  203.21  441.95      M            2008.0    Yellow    No Hair     100.0
# 1     NaN     NaN      M               NaN      Blue      Black     100.0
# 2  203.04  441.98      M               NaN     Green    No Hair      80.0
# 3     NaN     NaN      M               NaN      Blue      Blond      10.0
# 4  173.41   61.03      F               NaN      Blue      Blond       NaN
#
#   Intelligence
# 0     moderate
# 1         high
# 2         good
# ...

# %%
df.dtypes
# Out:
# Name                 object
# Identity             object
# Birth place          object
# Publisher            object
# Height              float64
# Weight              float64
# Gender               object
# First appearance    float64
# Eye color            object
# Hair color           object
# Strength            float64
# Intelligence         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681 entries, 0 to 680
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              681 non-null    object
#  1   Identity          581 non-null    object
#  2   Birth place       276 non-null    object
#  3   Publisher         670 non-null    object
#  4   Height            478 non-null    float64
#  5   Weight            461 non-null    float64
#  6   Gender            654 non-null    object
#  7   First appearance  341 non-null    float64
#  8   Eye color         520 non-null    object
#  9   Hair color        521 non-null    object
#  10  Strength          563 non-null    float64
#  11  Intelligence      563 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 64.0+ KB

# %%
df.isnull().sum()
# Out:
# Name                  0
# Identity            100
# Birth place         405
# Publisher            11
# Height              203
# Weight              220
# Gender               27
# First appearance    340
# Eye color           161
# Hair color          160
# Strength            118
# Intelligence        118
# dtype: int64

# %%
df.duplicated(subset = ['Name'], keep = 'last')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 676    False
# 677    False
# 678    False
# 679    False
# 680    False
# Length: 681, dtype: bool

# %%
df.replace(to_replace = '-', value = 'other', inplace = True)
df.head()
# Out:
#           Name                Identity         Birth place      Publisher  \
# 0       A-Bomb  Richard Milhouse Jones  Scarsdale, Arizona  Marvel Comics
# 1      Abraxas                 Abraxas    Within Eternity   Marvel Comics
# 2  Abomination            Emil Blonsky  Zagreb, Yugoslavia  Marvel Comics
# 3  Adam Monroe                     NaN                 NaN   NBC - Heroes
# 4     Agent 13           Sharon Carter                 NaN  Marvel Comics
#
#    Height  Weight Gender  First appearance Eye color Hair color  Strength  \
# 0  203.21  441.95      M            2008.0    Yellow    No Hair     100.0
# 1     NaN     NaN      M               NaN      Blue      Black     100.0
# 2  203.04  441.98      M               NaN     Green    No Hair      80.0
# 3     NaN     NaN      M               NaN      Blue      Blond      10.0
# 4  173.41   61.03      F               NaN      Blue      Blond       NaN
#
#   Intelligence
# 0     moderate
# 1         high
# 2         good
# ...

# %%
df['Publisher'].fillna('other', inplace = True)
df.head()
# Out:
#           Name                Identity         Birth place      Publisher  \
# 0       A-Bomb  Richard Milhouse Jones  Scarsdale, Arizona  Marvel Comics
# 1      Abraxas                 Abraxas    Within Eternity   Marvel Comics
# 2  Abomination            Emil Blonsky  Zagreb, Yugoslavia  Marvel Comics
# 3  Adam Monroe                     NaN                 NaN   NBC - Heroes
# 4     Agent 13           Sharon Carter                 NaN  Marvel Comics
#
#    Height  Weight Gender  First appearance Eye color Hair color  Strength  \
# 0  203.21  441.95      M            2008.0    Yellow    No Hair     100.0
# 1     NaN     NaN      M               NaN      Blue      Black     100.0
# 2  203.04  441.98      M               NaN     Green    No Hair      80.0
# 3     NaN     NaN      M               NaN      Blue      Blond      10.0
# 4  173.41   61.03      F               NaN      Blue      Blond       NaN
#
#   Intelligence
# 0     moderate
# 1         high
# 2         good
# ...

# %%
df  = df * 1
df.head(10)
# Out:
#           Name                Identity         Birth place          Publisher  \
# 0       A-Bomb  Richard Milhouse Jones  Scarsdale, Arizona      Marvel Comics
# 1      Abraxas                 Abraxas    Within Eternity       Marvel Comics
# 2  Abomination            Emil Blonsky  Zagreb, Yugoslavia      Marvel Comics
# 3  Adam Monroe                     NaN                 NaN       NBC - Heroes
# 4     Agent 13           Sharon Carter                 NaN      Marvel Comics
# 5    Agent Bob                     Bob                 NaN      Marvel Comics
# 6   Abe Sapien          Abraham Sapien                 NaN  Dark Horse Comics
# 7     Abin Sur                     NaN              Ungara          DC Comics
# 8       Angela                     NaN                 NaN       Image Comics
# 9   Animal Man          Bernhard Baker                 NaN          DC Comics
#
#    Height  Weight Gender  First appearance Eye color Hair color  Strength  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Identity', 'Birth place', 'Publisher', 'Height', 'Weight',
#        'Gender', 'First appearance', 'Eye color', 'Hair color', 'Strength',
#        'Intelligence'],
#       dtype='object')

# %%
df.sort_values(by = ['Strength'], ascending = (False))
# Out:
#                  Name                 Identity             Birth place  \
# 0              A-Bomb   Richard Milhouse Jones      Scarsdale, Arizona
# 505          Darkseid                     Uxas                     NaN
# 101    Superboy-Prime                   Kal-El  Krypton (Earth-Prime)
# 100         Supergirl              Kara Zor-El      Argo City, Krypton
# 98               Thor             Thor Odinson                  Asgard
# ..                ...                      ...                     ...
# 650           Arsenal  Roy William Harper, Jr.                     NaN
# 658          Atom III                Adam Cray                     NaN
# 668              Ammo                      NaN                     NaN
# 671  Allan Quatermain                      NaN                     NaN
# 674    Ando Masahashi           Ando Masahashi                     NaN
#
#          Publisher  Height  Weight Gender  First appearance Eye color  \
# ...

# %%
num_rows, num_columns = df.shape

# Print the results
print(f"Number of Rows: {num_rows}")
print(f"Number of Columns: {num_columns}")
# Out:
# Number of Rows: 681
# Number of Columns: 12

# %%
df.replace(to_replace = '-', value = 'other', inplace = True)
df.head()
# Out:
#           Name                Identity         Birth place      Publisher  \
# 0       A-Bomb  Richard Milhouse Jones  Scarsdale, Arizona  Marvel Comics
# 1      Abraxas                 Abraxas    Within Eternity   Marvel Comics
# 2  Abomination            Emil Blonsky  Zagreb, Yugoslavia  Marvel Comics
# 3  Adam Monroe                     NaN                 NaN   NBC - Heroes
# 4     Agent 13           Sharon Carter                 NaN  Marvel Comics
#
#    Height  Weight Gender  First appearance Eye color Hair color  Strength  \
# 0  203.21  441.95      M            2008.0    Yellow    No Hair     100.0
# 1     NaN     NaN      M               NaN      Blue      Black     100.0
# 2  203.04  441.98      M               NaN     Green    No Hair      80.0
# 3     NaN     NaN      M               NaN      Blue      Blond      10.0
# 4  173.41   61.03      F               NaN      Blue      Blond       NaN
#
#   Intelligence
# 0     moderate
# 1         high
# 2         good
# ...
